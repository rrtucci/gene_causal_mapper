# %% [markdown]
# # Drosophila melanogaster Embryogenesis Dataset (GEO: GSE121160)
#    * **Description**: This dataset includes time-course gene expression data during *Drosophila melanogaster* embryogenesis, covering 14 time points (0, 1, 2, 3, 4, 5, 6, 8, 10, 12, 14, 16, 18, and 20 hours). It features RNA sequencing (RNA-Seq) data for thousands of genes, including transcription factors and their targets. The study also pairs this with proteome data, but the transcriptome portion alone provides gene expression dynamics over time.
#    * **Why It Fits**: It tracks gene expression across multiple developmental stages, and among the 7,640 genes analyzed, 791 are classified as regulators (e.g., transcription factors involved in replication, transcription, etc.). This allows you to study both transcription factor activity and downstream gene expression changes over time.
#    * **Access**: Available at NCBI GEO under accession number GSE121160 ([https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE121160](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE121160)).

# %%
import GEOparse
from pprint import pprint

gse_id = "GSE121160"
gse = GEOparse.get_GEO(geo=gse_id, destdir="../"+ gse_id + "_data")

# Show metadata
pprint(gse.metadata)
# Out:
# 23-Mar-2025 20:12:50 DEBUG utils - Directory ../GSE121160_data already exists. Skipping.
# 23-Mar-2025 20:12:50 INFO GEOparse - File already exist: using local version.
# 23-Mar-2025 20:12:50 INFO GEOparse - Parsing ../GSE121160_data\GSE121160_family.soft.gz:
# 23-Mar-2025 20:12:50 DEBUG GEOparse - DATABASE: GeoMiame
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SERIES: GSE121160
# 23-Mar-2025 20:12:50 DEBUG GEOparse - PLATFORM: GPL17275
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427100
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427101
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427102
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427103
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427104
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427105
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427106
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427107
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427108
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427109
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427110
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427111
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427112
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427113
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427114
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427115
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427116
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427117
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427118
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427119
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427120
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427121
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427122
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427123
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427124
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427125
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427126
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427127
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427128
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427129
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427130
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427131
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427132
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427133
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427134
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427135
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427136
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427137
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427138
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427139
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427140
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427141
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427142
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427143
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427144
# 23-Mar-2025 20:12:50 DEBUG GEOparse - SAMPLE: GSM3427145
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427146
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427147
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427148
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427149
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427150
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427151
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427152
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427153
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427154
# 23-Mar-2025 20:12:51 DEBUG GEOparse - SAMPLE: GSM3427155
# {'contact_address': ['Ackermannweg 4'],
#  'contact_city': ['Mainz'],
#  'contact_country': ['Germany'],
#  'contact_institute': ['Institute of Molecular Biology, Mainz'],
#  'contact_name': ['Sergi,,Sayols'],
#  'contact_zip/postal_code': ['55128'],
#  'contributor': ['Falk,,Butter', 'Kolja,,Becker', 'Stefan,,Legewie'],
#  'geo_accession': ['GSE121160'],
#  'last_update_date': ['Mar 25 2019'],
#  'overall_design': ['Whole embryos of Drosophila melanogaster measured at 14 '
#                     'time points during the first 20h of development (0h, 1h, '
#                     '2h, 3h, 4h, 5h, 6h, 8h, 10h, 12h, 14h, 16h, 18h, 20h). '
#                     'Each sample was measured in biological quadruplicates. '
#                     'RNAseq samples correspond to proteome measurements '
#                     'deposited in ProteomeXchange as PXD005713.'],
#  'platform_id': ['GPL17275'],
#  'platform_taxid': ['7227'],
#  'pubmed_id': ['30478415'],
#  'relation': ['SubSeries of: GSE121167',
#               'BioProject: https://www.ncbi.nlm.nih.gov/bioproject/PRJNA495910',
#               'SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRP165272'],
#  'sample_id': ['GSM3427100',
#                'GSM3427101',
#                'GSM3427102',
#                'GSM3427103',
#                'GSM3427104',
#                'GSM3427105',
#                'GSM3427106',
#                'GSM3427107',
#                'GSM3427108',
#                'GSM3427109',
#                'GSM3427110',
#                'GSM3427111',
#                'GSM3427112',
#                'GSM3427113',
#                'GSM3427114',
#                'GSM3427115',
#                'GSM3427116',
#                'GSM3427117',
#                'GSM3427118',
#                'GSM3427119',
#                'GSM3427120',
#                'GSM3427121',
#                'GSM3427122',
#                'GSM3427123',
#                'GSM3427124',
#                'GSM3427125',
#                'GSM3427126',
#                'GSM3427127',
#                'GSM3427128',
#                'GSM3427129',
#                'GSM3427130',
#                'GSM3427131',
#                'GSM3427132',
#                'GSM3427133',
#                'GSM3427134',
#                'GSM3427135',
#                'GSM3427136',
#                'GSM3427137',
#                'GSM3427138',
#                'GSM3427139',
#                'GSM3427140',
#                'GSM3427141',
#                'GSM3427142',
#                'GSM3427143',
#                'GSM3427144',
#                'GSM3427145',
#                'GSM3427146',
#                'GSM3427147',
#                'GSM3427148',
#                'GSM3427149',
#                'GSM3427150',
#                'GSM3427151',
#                'GSM3427152',
#                'GSM3427153',
#                'GSM3427154',
#                'GSM3427155'],
#  'sample_taxid': ['7227'],
#  'status': ['Public on Oct 13 2018'],
#  'submission_date': ['Oct 12 2018'],
#  'summary': ['Proteome and transcriptome often show poor correlation, '
#              'hindering the system-wide analysis of post-transcriptional '
#              'regulation. Here, the authors study proteome and transcriptome '
#              'dynamics during Drosophila embryogenesis and present basic '
#              'mathematical models describing the temporal regulation of most '
#              'protein-RNA pairs.'],
#  'supplementary_file': ['ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE121nnn/GSE121160/suppl/GSE121160_RAW.tar'],
#  'title': ['Quantifying post-transcriptional regulation in the development of '
#            'Drosophila melanogaster [devel]'],
#  'type': ['Expression profiling by high throughput sequencing']}

# %%
# Show sample names
pprint(gse.gsms.keys())
# Out:
# dict_keys(['GSM3427100', 'GSM3427101', 'GSM3427102', 'GSM3427103', 'GSM3427104', 'GSM3427105', 'GSM3427106', 'GSM3427107', 'GSM3427108', 'GSM3427109', 'GSM3427110', 'GSM3427111', 'GSM3427112', 'GSM3427113', 'GSM3427114', 'GSM3427115', 'GSM3427116', 'GSM3427117', 'GSM3427118', 'GSM3427119', 'GSM3427120', 'GSM3427121', 'GSM3427122', 'GSM3427123', 'GSM3427124', 'GSM3427125', 'GSM3427126', 'GSM3427127', 'GSM3427128', 'GSM3427129', 'GSM3427130', 'GSM3427131', 'GSM3427132', 'GSM3427133', 'GSM3427134', 'GSM3427135', 'GSM3427136', 'GSM3427137', 'GSM3427138', 'GSM3427139', 'GSM3427140', 'GSM3427141', 'GSM3427142', 'GSM3427143', 'GSM3427144', 'GSM3427145', 'GSM3427146', 'GSM3427147', 'GSM3427148', 'GSM3427149', 'GSM3427150', 'GSM3427151', 'GSM3427152', 'GSM3427153', 'GSM3427154', 'GSM3427155'])

# %%
import tarfile
import os
import gzip
import shutil
import pandas as pd

# Step 1: Download data
gse = GEOparse.get_GEO(geo="GSE121160", destdir="./GSE121160_data", include_data=True, silent=False)

# Step 2: Extract .tar file
tar_file = "../GSE121160_data/GSE121160_RAW.tar"
extract_dir = "../GSE121160_data/extracted"

# Check if .tar file exists
if os.path.exists(tar_file):
    try:
        with tarfile.open(tar_file, "r") as tar:
            tar.extractall(path=extract_dir)
        print(f"Extracted .tar to {extract_dir}")
    except Exception as e:
        print(f"Error extracting {tar_file}: {e}")
        exit()
else:
    print(f"No .tar file found at {tar_file}. Listing files in ./GSE121160_data:")
    print(os.listdir("./GSE121160_data"))
    extract_dir = "./GSE121160_data"  # Fallback to base directory if no .tar

# Step 3: Ensure extract_dir exists
if not os.path.exists(extract_dir):
    print(f"Directory {extract_dir} does not exist. Creating it.")
    os.makedirs(extract_dir)
else:
    print(f"Using directory: {extract_dir}")
    print(f"Files in {extract_dir}: {os.listdir(extract_dir)}")

# Step 4: Decompress .tsv.gz files
tsv_gz_found = False
for file in os.listdir(extract_dir):
    if file.endswith(".tsv.gz"):
        tsv_gz_found = True
        gz_file = os.path.join(extract_dir, file)
        tsv_file = os.path.join(extract_dir, file.replace(".gz", ""))
        try:
            with gzip.open(gz_file, "rb") as f_in:
                with open(tsv_file, "wb") as f_out:
                    shutil.copyfileobj(f_in, f_out)
            print(f"Decompressed {file} to {tsv_file}")
        except Exception as e:
            print(f"Error decompressing {gz_file}: {e}")

if not tsv_gz_found:
    print(f"No .tsv.gz files found in {extract_dir}")

# Step 5: Read TSV files
tsv_files = [f for f in os.listdir(extract_dir) if f.endswith(".tsv")]
for tsv_file in tsv_files:
    file_path = os.path.join(extract_dir, tsv_file)
    print(f"\nProcessing {tsv_file}")
    
    # Load TSV into DataFrame
    try:
        df = pd.read_csv(file_path, sep="\t")
        print(f"Shape: {df.shape}")
        print("Columns:", df.columns.tolist())
        print("First few rows:")
        print(df.head())
    except Exception as e:
        print(f"Error reading {tsv_file}: {e}")

# Step 6: Link to samples
print("\nMatching TSV files to samples:")
for gsm_name, gsm in gse.gsms.items():
    for sup_file in gsm.metadata.get("supplementary_file", []):
        sup_file_name = sup_file.split("/")[-1].replace(".gz", "")
        if sup_file_name in tsv_files:
            print(f"Sample {gsm_name} ({gsm.metadata['title']}) -> {sup_file_name}")
# Out:
# 23-Mar-2025 18:02:41 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE121nnn/GSE121160/soft/GSE121160_family.soft.gz to ./GSE121160_data\GSE121160_family.soft.gz
# 100%|███████████████████████████████████████████████████████████████████| 5.05k/5.05k [00:00<00:00, 35.9kB/s]
# 23-Mar-2025 18:02:42 DEBUG downloader - Size validation passed
# 23-Mar-2025 18:02:42 DEBUG downloader - Moving C:\Users\rrtuc\AppData\Local\Temp\tmp7n9pgzam to C:\Users\rrtuc\Desktop\backed-up\python-projects\gene_causal_mapper\jupyter_notebooks\GSE121160_data\GSE121160_family.soft.gz
# 23-Mar-2025 18:02:42 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE121nnn/GSE121160/soft/GSE121160_family.soft.gz
# 23-Mar-2025 18:02:42 INFO GEOparse - Parsing ./GSE121160_data\GSE121160_family.soft.gz:
# 23-Mar-2025 18:02:42 DEBUG GEOparse - DATABASE: GeoMiame
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SERIES: GSE121160
# 23-Mar-2025 18:02:42 DEBUG GEOparse - PLATFORM: GPL17275
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427100
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427101
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427102
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427103
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427104
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427105
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427106
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427107
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427108
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427109
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427110
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427111
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427112
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427113
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427114
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427115
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427116
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427117
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427118
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427119
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427120
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427121
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427122
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427123
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427124
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427125
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427126
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427127
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427128
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427129
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427130
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427131
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427132
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427133
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427134
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427135
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427136
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427137
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427138
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427139
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427140
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427141
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427142
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427143
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427144
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427145
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427146
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427147
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427148
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427149
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427150
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427151
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427152
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427153
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427154
# 23-Mar-2025 18:02:42 DEBUG GEOparse - SAMPLE: GSM3427155
# Extracted .tar to ../GSE121160_data/extracted
# Using directory: ../GSE121160_data/extracted
# Files in ../GSE121160_data/extracted: ['GSM3427100_00h_1.tsv.gz', 'GSM3427101_00h_2.tsv.gz', 'GSM3427102_00h_3.tsv.gz', 'GSM3427103_00h_4.tsv.gz', 'GSM3427104_01h_1.tsv.gz', 'GSM3427105_01h_2.tsv.gz', 'GSM3427106_01h_3.tsv.gz', 'GSM3427107_01h_4.tsv.gz', 'GSM3427108_02h_1.tsv.gz', 'GSM3427109_02h_2.tsv.gz', 'GSM3427110_02h_3.tsv.gz', 'GSM3427111_02h_4.tsv.gz', 'GSM3427112_03h_1.tsv.gz', 'GSM3427113_03h_2.tsv.gz', 'GSM3427114_03h_3.tsv.gz', 'GSM3427115_03h_4.tsv.gz', 'GSM3427116_04h_1.tsv.gz', 'GSM3427117_04h_2.tsv.gz', 'GSM3427118_04h_3.tsv.gz', 'GSM3427119_04h_4.tsv.gz', 'GSM3427120_05h_1.tsv.gz', 'GSM3427121_05h_2.tsv.gz', 'GSM3427122_05h_3.tsv.gz', 'GSM3427123_05h_4.tsv.gz', 'GSM3427124_06h_1.tsv.gz', 'GSM3427125_06h_2.tsv.gz', 'GSM3427126_06h_3.tsv.gz', 'GSM3427127_06h_4.tsv.gz', 'GSM3427128_08h_1.tsv.gz', 'GSM3427129_08h_2.tsv.gz', 'GSM3427130_08h_3.tsv.gz', 'GSM3427131_08h_4.tsv.gz', 'GSM3427132_10h_1.tsv.gz', 'GSM3427133_10h_2.tsv.gz', 'GSM3427134_10h_3.tsv.gz', 'GSM3427135_10h_4.tsv.gz', 'GSM3427136_12h_1.tsv.gz', 'GSM3427137_12h_2.tsv.gz', 'GSM3427138_12h_3.tsv.gz', 'GSM3427139_12h_4.tsv.gz', 'GSM3427140_14h_1.tsv.gz', 'GSM3427141_14h_2.tsv.gz', 'GSM3427142_14h_3.tsv.gz', 'GSM3427143_14h_4.tsv.gz', 'GSM3427144_16h_1.tsv.gz', 'GSM3427145_16h_2.tsv.gz', 'GSM3427146_16h_3.tsv.gz', 'GSM3427147_16h_4.tsv.gz', 'GSM3427148_18h_1.tsv.gz', 'GSM3427149_18h_2.tsv.gz', 'GSM3427150_18h_3.tsv.gz', 'GSM3427151_18h_4.tsv.gz', 'GSM3427152_20h_1.tsv.gz', 'GSM3427153_20h_2.tsv.gz', 'GSM3427154_20h_3.tsv.gz', 'GSM3427155_20h_4.tsv.gz']
# Decompressed GSM3427100_00h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427100_00h_1.tsv
# Decompressed GSM3427101_00h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427101_00h_2.tsv
# Decompressed GSM3427102_00h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427102_00h_3.tsv
# Decompressed GSM3427103_00h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427103_00h_4.tsv
# Decompressed GSM3427104_01h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427104_01h_1.tsv
# Decompressed GSM3427105_01h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427105_01h_2.tsv
# Decompressed GSM3427106_01h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427106_01h_3.tsv
# Decompressed GSM3427107_01h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427107_01h_4.tsv
# Decompressed GSM3427108_02h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427108_02h_1.tsv
# Decompressed GSM3427109_02h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427109_02h_2.tsv
# Decompressed GSM3427110_02h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427110_02h_3.tsv
# Decompressed GSM3427111_02h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427111_02h_4.tsv
# Decompressed GSM3427112_03h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427112_03h_1.tsv
# Decompressed GSM3427113_03h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427113_03h_2.tsv
# Decompressed GSM3427114_03h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427114_03h_3.tsv
# Decompressed GSM3427115_03h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427115_03h_4.tsv
# Decompressed GSM3427116_04h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427116_04h_1.tsv
# Decompressed GSM3427117_04h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427117_04h_2.tsv
# Decompressed GSM3427118_04h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427118_04h_3.tsv
# Decompressed GSM3427119_04h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427119_04h_4.tsv
# Decompressed GSM3427120_05h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427120_05h_1.tsv
# Decompressed GSM3427121_05h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427121_05h_2.tsv
# Decompressed GSM3427122_05h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427122_05h_3.tsv
# Decompressed GSM3427123_05h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427123_05h_4.tsv
# Decompressed GSM3427124_06h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427124_06h_1.tsv
# Decompressed GSM3427125_06h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427125_06h_2.tsv
# Decompressed GSM3427126_06h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427126_06h_3.tsv
# Decompressed GSM3427127_06h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427127_06h_4.tsv
# Decompressed GSM3427128_08h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427128_08h_1.tsv
# Decompressed GSM3427129_08h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427129_08h_2.tsv
# Decompressed GSM3427130_08h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427130_08h_3.tsv
# Decompressed GSM3427131_08h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427131_08h_4.tsv
# Decompressed GSM3427132_10h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427132_10h_1.tsv
# Decompressed GSM3427133_10h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427133_10h_2.tsv
# Decompressed GSM3427134_10h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427134_10h_3.tsv
# Decompressed GSM3427135_10h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427135_10h_4.tsv
# Decompressed GSM3427136_12h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427136_12h_1.tsv
# Decompressed GSM3427137_12h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427137_12h_2.tsv
# Decompressed GSM3427138_12h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427138_12h_3.tsv
# Decompressed GSM3427139_12h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427139_12h_4.tsv
# Decompressed GSM3427140_14h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427140_14h_1.tsv
# Decompressed GSM3427141_14h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427141_14h_2.tsv
# Decompressed GSM3427142_14h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427142_14h_3.tsv
# Decompressed GSM3427143_14h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427143_14h_4.tsv
# Decompressed GSM3427144_16h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427144_16h_1.tsv
# Decompressed GSM3427145_16h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427145_16h_2.tsv
# Decompressed GSM3427146_16h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427146_16h_3.tsv
# Decompressed GSM3427147_16h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427147_16h_4.tsv
# Decompressed GSM3427148_18h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427148_18h_1.tsv
# Decompressed GSM3427149_18h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427149_18h_2.tsv
# Decompressed GSM3427150_18h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427150_18h_3.tsv
# Decompressed GSM3427151_18h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427151_18h_4.tsv
# Decompressed GSM3427152_20h_1.tsv.gz to ../GSE121160_data/extracted\GSM3427152_20h_1.tsv
# Decompressed GSM3427153_20h_2.tsv.gz to ../GSE121160_data/extracted\GSM3427153_20h_2.tsv
# Decompressed GSM3427154_20h_3.tsv.gz to ../GSE121160_data/extracted\GSM3427154_20h_3.tsv
# Decompressed GSM3427155_20h_4.tsv.gz to ../GSE121160_data/extracted\GSM3427155_20h_4.tsv
#
# Processing GSM3427100_00h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   677
# 1  FBgn0000014   232
# 2  FBgn0000015    77
# 3  FBgn0000017  4827
# 4  FBgn0000018   202
#
# Processing GSM3427101_00h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   609
# 1  FBgn0000014   129
# 2  FBgn0000015    68
# 3  FBgn0000017  5001
# 4  FBgn0000018   184
#
# Processing GSM3427102_00h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   901
# 1  FBgn0000014   267
# 2  FBgn0000015    99
# 3  FBgn0000017  5753
# 4  FBgn0000018   258
#
# Processing GSM3427103_00h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   856
# 1  FBgn0000014    24
# 2  FBgn0000015    10
# 3  FBgn0000017  5690
# 4  FBgn0000018   235
#
# Processing GSM3427104_01h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1531
# 1  FBgn0000014    67
# 2  FBgn0000015    37
# 3  FBgn0000017  6433
# 4  FBgn0000018   327
#
# Processing GSM3427105_01h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1475
# 1  FBgn0000014   121
# 2  FBgn0000015    48
# 3  FBgn0000017  6756
# 4  FBgn0000018   365
#
# Processing GSM3427106_01h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1444
# 1  FBgn0000014    16
# 2  FBgn0000015    10
# 3  FBgn0000017  6586
# 4  FBgn0000018   363
#
# Processing GSM3427107_01h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1160
# 1  FBgn0000014    20
# 2  FBgn0000015    11
# 3  FBgn0000017  4871
# 4  FBgn0000018   376
#
# Processing GSM3427108_02h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   568
# 1  FBgn0000014   149
# 2  FBgn0000015    68
# 3  FBgn0000017  7504
# 4  FBgn0000018   165
#
# Processing GSM3427109_02h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   583
# 1  FBgn0000014   141
# 2  FBgn0000015    83
# 3  FBgn0000017  7511
# 4  FBgn0000018   187
#
# Processing GSM3427110_02h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   466
# 1  FBgn0000014   106
# 2  FBgn0000015    47
# 3  FBgn0000017  6560
# 4  FBgn0000018   155
#
# Processing GSM3427111_02h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   592
# 1  FBgn0000014   129
# 2  FBgn0000015    66
# 3  FBgn0000017  8100
# 4  FBgn0000018   179
#
# Processing GSM3427112_03h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   148
# 1  FBgn0000014   690
# 2  FBgn0000015   468
# 3  FBgn0000017  3368
# 4  FBgn0000018   103
#
# Processing GSM3427113_03h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   127
# 1  FBgn0000014   417
# 2  FBgn0000015   247
# 3  FBgn0000017  5001
# 4  FBgn0000018   111
#
# Processing GSM3427114_03h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   274
# 1  FBgn0000014  1279
# 2  FBgn0000015   988
# 3  FBgn0000017   874
# 4  FBgn0000018   163
#
# Processing GSM3427115_03h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   271
# 1  FBgn0000014  1455
# 2  FBgn0000015   957
# 3  FBgn0000017   687
# 4  FBgn0000018   185
#
# Processing GSM3427116_04h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   284
# 1  FBgn0000014  1060
# 2  FBgn0000015   671
# 3  FBgn0000017  1052
# 4  FBgn0000018   145
#
# Processing GSM3427117_04h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003    0
# 0  FBgn0000008  185
# 1  FBgn0000014  832
# 2  FBgn0000015  522
# 3  FBgn0000017  708
# 4  FBgn0000018  129
#
# Processing GSM3427118_04h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   188
# 1  FBgn0000014  1045
# 2  FBgn0000015   766
# 3  FBgn0000017   676
# 4  FBgn0000018   156
#
# Processing GSM3427119_04h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003    0
# 0  FBgn0000008  154
# 1  FBgn0000014  984
# 2  FBgn0000015  702
# 3  FBgn0000017  788
# 4  FBgn0000018  142
#
# Processing GSM3427120_05h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   229
# 1  FBgn0000014  1531
# 2  FBgn0000015  1006
# 3  FBgn0000017  1390
# 4  FBgn0000018   185
#
# Processing GSM3427121_05h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   262
# 1  FBgn0000014  1621
# 2  FBgn0000015  1008
# 3  FBgn0000017   753
# 4  FBgn0000018   175
#
# Processing GSM3427122_05h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   230
# 1  FBgn0000014  1430
# 2  FBgn0000015   939
# 3  FBgn0000017   670
# 4  FBgn0000018   172
#
# Processing GSM3427123_05h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   203
# 1  FBgn0000014  1416
# 2  FBgn0000015   971
# 3  FBgn0000017   759
# 4  FBgn0000018   145
#
# Processing GSM3427124_06h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   354
# 1  FBgn0000014  2287
# 2  FBgn0000015  1361
# 3  FBgn0000017   830
# 4  FBgn0000018   219
#
# Processing GSM3427125_06h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   213
# 1  FBgn0000014  1563
# 2  FBgn0000015  1073
# 3  FBgn0000017   583
# 4  FBgn0000018   179
#
# Processing GSM3427126_06h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   339
# 1  FBgn0000014  1906
# 2  FBgn0000015  1313
# 3  FBgn0000017   956
# 4  FBgn0000018   163
#
# Processing GSM3427127_06h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   405
# 1  FBgn0000014  2188
# 2  FBgn0000015  1248
# 3  FBgn0000017  1029
# 4  FBgn0000018   194
#
# Processing GSM3427128_08h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   315
# 1  FBgn0000014  3431
# 2  FBgn0000015  2019
# 3  FBgn0000017  1240
# 4  FBgn0000018   220
#
# Processing GSM3427129_08h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   258
# 1  FBgn0000014  3424
# 2  FBgn0000015  1919
# 3  FBgn0000017  1043
# 4  FBgn0000018   195
#
# Processing GSM3427130_08h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   323
# 1  FBgn0000014  4716
# 2  FBgn0000015  2613
# 3  FBgn0000017  1458
# 4  FBgn0000018   247
#
# Processing GSM3427131_08h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   278
# 1  FBgn0000014  3636
# 2  FBgn0000015  2146
# 3  FBgn0000017  1148
# 4  FBgn0000018   181
#
# Processing GSM3427132_10h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   567
# 1  FBgn0000014  4765
# 2  FBgn0000015  2785
# 3  FBgn0000017  1821
# 4  FBgn0000018   242
#
# Processing GSM3427133_10h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   503
# 1  FBgn0000014  3501
# 2  FBgn0000015  2059
# 3  FBgn0000017  1578
# 4  FBgn0000018   193
#
# Processing GSM3427134_10h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   578
# 1  FBgn0000014  4349
# 2  FBgn0000015  2688
# 3  FBgn0000017  1806
# 4  FBgn0000018   199
#
# Processing GSM3427135_10h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   474
# 1  FBgn0000014  3383
# 2  FBgn0000015  2097
# 3  FBgn0000017  1815
# 4  FBgn0000018   209
#
# Processing GSM3427136_12h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   735
# 1  FBgn0000014  3023
# 2  FBgn0000015  1522
# 3  FBgn0000017  1801
# 4  FBgn0000018   122
#
# Processing GSM3427137_12h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   643
# 1  FBgn0000014  3936
# 2  FBgn0000015  2221
# 3  FBgn0000017  2048
# 4  FBgn0000018   169
#
# Processing GSM3427138_12h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   746
# 1  FBgn0000014  4255
# 2  FBgn0000015  2479
# 3  FBgn0000017  2209
# 4  FBgn0000018   176
#
# Processing GSM3427139_12h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   793
# 1  FBgn0000014  3556
# 2  FBgn0000015  1729
# 3  FBgn0000017  2087
# 4  FBgn0000018   175
#
# Processing GSM3427140_14h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2029
# 1  FBgn0000014  4104
# 2  FBgn0000015  1933
# 3  FBgn0000017  2781
# 4  FBgn0000018   189
#
# Processing GSM3427141_14h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1292
# 1  FBgn0000014  1683
# 2  FBgn0000015   880
# 3  FBgn0000017  1359
# 4  FBgn0000018   137
#
# Processing GSM3427142_14h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2179
# 1  FBgn0000014  4309
# 2  FBgn0000015  1946
# 3  FBgn0000017  2891
# 4  FBgn0000018   196
#
# Processing GSM3427143_14h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1612
# 1  FBgn0000014  3665
# 2  FBgn0000015  1759
# 3  FBgn0000017  1464
# 4  FBgn0000018   217
#
# Processing GSM3427144_16h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2368
# 1  FBgn0000014  3575
# 2  FBgn0000015  1496
# 3  FBgn0000017  2548
# 4  FBgn0000018   140
#
# Processing GSM3427145_16h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1753
# 1  FBgn0000014  3266
# 2  FBgn0000015  1504
# 3  FBgn0000017  1687
# 4  FBgn0000018   158
#
# Processing GSM3427146_16h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2030
# 1  FBgn0000014  3315
# 2  FBgn0000015  1586
# 3  FBgn0000017  1608
# 4  FBgn0000018   168
#
# Processing GSM3427147_16h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2444
# 1  FBgn0000014  2613
# 2  FBgn0000015  1343
# 3  FBgn0000017  2448
# 4  FBgn0000018   170
#
# Processing GSM3427148_18h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1653
# 1  FBgn0000014  2964
# 2  FBgn0000015  1612
# 3  FBgn0000017  1812
# 4  FBgn0000018   131
#
# Processing GSM3427149_18h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1295
# 1  FBgn0000014  2233
# 2  FBgn0000015  1417
# 3  FBgn0000017  1746
# 4  FBgn0000018   120
#
# Processing GSM3427150_18h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1282
# 1  FBgn0000014  2423
# 2  FBgn0000015  1228
# 3  FBgn0000017  1748
# 4  FBgn0000018   110
#
# Processing GSM3427151_18h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1494
# 1  FBgn0000014  2359
# 2  FBgn0000015  1110
# 3  FBgn0000017  1884
# 4  FBgn0000018   104
#
# Processing GSM3427152_20h_1.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  1215
# 1  FBgn0000014  2980
# 2  FBgn0000015  1256
# 3  FBgn0000017  1762
# 4  FBgn0000018   106
#
# Processing GSM3427153_20h_2.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008  2288
# 1  FBgn0000014  3319
# 2  FBgn0000015  1622
# 3  FBgn0000017  2713
# 4  FBgn0000018   162
#
# Processing GSM3427154_20h_3.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   528
# 1  FBgn0000014  1835
# 2  FBgn0000015   970
# 3  FBgn0000017  1430
# 4  FBgn0000018   117
#
# Processing GSM3427155_20h_4.tsv
# Shape: (17562, 2)
# Columns: ['FBgn0000003', '0']
# First few rows:
#    FBgn0000003     0
# 0  FBgn0000008   375
# 1  FBgn0000014  1052
# 2  FBgn0000015   653
# 3  FBgn0000017   880
# 4  FBgn0000018    63
#
# Matching TSV files to samples:
